# %%
import pandas as pd
from tqdm import tqdm
import os
import openai
from glob import glob
import re

# %%
cous = pd.read_pickle('../data/processed/counts_of_unique_subjects.pickle')

# %%
cous.sum(axis=1).sort_values(ascending=False).iloc[:30]
# Out:
# pld
# www.coursera.org               7520.0
# www.edx.org                    7407.0
# studylib.net                   5646.0
# www.diziler.com                4683.0
# www.physicsforums.com          4677.0
# ja.coursera.org                3851.0
# ru.coursera.org                3784.0
# pt.coursera.org                3601.0
# fr.coursera.org                3375.0
# zh.coursera.org                3353.0
# es.coursera.org                3336.0
# de.coursera.org                3162.0
# ko.coursera.org                3053.0
# codegalaxy.io                  3026.0
# zh-tw.coursera.org             3023.0
# www.goconqr.com                2471.0
# www.lynda.com                  2017.0
# www.verboeducacional.com.br    1526.0
# www.taskutark.ee               1143.0
# drops.dagstuhl.de              1135.0
# www.haberankara.com            1113.0
# www.lumoslearning.com          1013.0
# mille-sorties.com               895.0
# quiwego.com                     848.0
# redooc.com                      832.0
# studylibpl.com                  744.0
# www.habermarmara.com.tr         718.0
# www.gettasting.com              699.0
# ru.codegalaxy.io                646.0
# studylib.ru                     624.0
# dtype: float64

# %%
top_ed_domain_data_files = glob('../data/processed/pld_data/*.csv')

# %%
top_ed_data = [(f, pd.read_csv(f, index_col=0)) for f in top_ed_domain_data_files]

# %%
def get_name_year(path):
    filename = path.split('/')[-1]
    name = filename.replace('.csv', '')
    pld, year = re.findall('([a-z_]+)_([0-9]+)', name)[0]
    year = int(year)
    pld = pld.replace('_', '.')
    return pld, year

# [(get_name_year(f), df.shape[0]) for (f, df) in top_ed_data]

# %%
def summary_stats(filepath, df):
    pld, year = get_name_year(filepath)
    s_count = df.s.nunique()
    p_count = df.p.nunique()
    ps_per_s_count = df.groupby('s').p.nunique().mean()
    return pd.Series({
        'pld': pld,
        'year': year,
        'ps_per_s_count': ps_per_s_count,
        's_count': s_count,
        'p_count': p_count
    })

sum_stats = pd.DataFrame([summary_stats(f, df) for (f, df) in top_ed_data]).groupby('pld').s_count.apply(list)

# %%
def get_title_desc(df):
    o_str_exists = (df.o.notna()) & (df.o.str.strip().str.len() > 0)
    descriptions = df[(df.p.str.contains('description')) & o_str_exists].o
    title = df[df.p.str.contains('name') & o_str_exists].o
    if (descriptions.shape[0] > 0) and (title.shape[0] > 0):
        return pd.Series({'desc': descriptions.iloc[0],
                          'title': title.iloc[0]})
    else:
        return pd.Series({'desc': None, 'title': None})


def prompt_template(title, description):
    return f"""The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.

    Text: \"\"\"Title: {title} Description: {description}\"\"\"

    Learning objectives, subject and student level:"""
    
prompts = []
for ed_data in top_ed_data:
    domain, year = get_name_year(ed_data[0])
    if ed_data[1].shape[0] > 0:
        title_descs = ed_data[1].groupby('s').apply(get_title_desc)
        for _, row in title_descs.iterrows():
            prompts.append({'domain': domain, 'year': year, 'title' : row.title, 'desc': row.desc, 
                            'prompt': prompt_template(row.title, row.desc)})
    
prompts = pd.DataFrame(prompts).drop_duplicates(subset=['prompt'])
prompts = prompts[prompts.desc.notna() & prompts.title.notna()]
from hashlib import md5
prompts['hashed_prompt'] = prompts.prompt.apply(lambda p: str(md5(p.encode('utf-8')).hexdigest()))

# %%
completed = glob('../data/gpt_results/*.completion_temp_07')
completed = [c.split('/')[-1].split('.')[0] for c in completed]

# %%
prompts[prompts.hashed_prompt.isin()]
# Out:
# ['11c20f4567d5ca193395ced206023663',
#  '918e206172e9088a7e73accaf4af9571',
#  '35940e783db1d6b4e8bb463aa855d3f9',
#  'b657bfaec4859c081b17c7e679e4ecbd',
#  '6c6b2b86301045c40ecb2d381e0d9377',
#  'd45d0507087672fecf64cf0705ef649c',
#  'ffeec8def26e2b03411361cd1ffdce2e',
#  'e81de8016850221cec739eda215dcf1a',
#  '614f4b90fb12c118da3c4f82ea064411',
#  '5ca23561ff249ebc66e6f888d6b82d23',
#  '229a6c815590e6436e0ad304c22ecf4c',
#  '7c6480d91327c23a398b3ebe602d5f47',
#  '00a437ac61145672b6eda50f6035f045',
#  '6bcf96e2798e4e2b17d72f6b235cb922',
#  'a4ae6bb1711503b5aaa0b132a1c777ed',
#  '142ecb6fb81fc3efc1b22ecda6aa0692',
#  'c3cc470eb17dc6f7409d3ff50183c136',
#  '372908bf3efac1d48c478a95ff05be86',
#  'fd279a7ccc2c74c2cec02b6245519ee5',
#  '8d8e4931eb30dee52923c7d2f9aca85a',
#  '2005f8ff4da82ac955cba82bdef9910a',
#  '2c19eea10189003c000cfaf969f69520',
#  'db762b6a535973fb9750f1934f2c37ef',
#  'e764b8e9c84d4361b2b75c1d8711d30f',
#  'ad1694c17159aab3b9c54ae8a14619c0',
#  'e361269fedf9f45642da1b0497fcb098',
#  'c4d6b4425d44445196131a1278a9996d',
#  '57ca96aca1e75efbbb0c9e591c27b31a',
#  '0618eebe699eec59e812df87976e812d',
#  '6eb18d97f4b4a07ed5f48f507d448702',
#  '8dbf0a62de2cefa28238ce36c22e7489',
#  '2ab3933cb06664af4cd7670fe0e0f9de']

# %%
sample_prompts = prompts.groupby('domain').sample(frac=0.33)

# %%
sample_prompts.head(2)
# Out:
#                 domain  year                              title  \
# 13455  es.coursera.org  2021    Business English: Final Project
# 14032  es.coursera.org  2021  Managing Security in Google Cloud
#
#                                                     desc  \
# 13455  Ofrecido por Universidad del Estado de Arizona...
# 14032  Ofrecido por Google Cloud. This self-paced tra...
#
#                                                   prompt  \
# 13455  The following text is the title and descriptio...
# 14032  The following text is the title and descriptio...
#
#                           hashed_prompt
# 13455  5027a9f6729e9e622232ad2c5743f5c0
# 14032  2d7f967dff41b3da101f10f9535fa28f

# %%
# !mkdir ../data/gpt_results

# %%
gpt_model='text-davinci-003'

# %%
gpt_temperature=0.1

# %%
gpt_max_length = 256

# %%
# sample_prompts.to_pickle('../data/sample_prompts.pickle')

# %%
sample_prompts = pd.read_pickle('../data/sample_prompts.pickle')

# %%
def save_completion_to_file_if_not_exists(filename, prompt):
    if not os.path.exists(filename):
        completion = generate_text(prompt)
        with open(filename, 'w') as f:
            if completion is not None:
                f.write(completion)
            else:
                f.write("NO_COMPLETION")
            print(f"File '{filename}' created and contents saved successfully.")
    else:
        print(f"File '{filename}' already exists. Contents not saved.")
        
openai.api_key = os.environ["OPENAI_API_KEY"]  # Set your API key as an environment variable

def generate_text(prompt, model=gpt_model, temperature=gpt_temperature, max_tokens=gpt_max_length):
    try:
        response = openai.Completion.create(
            engine=model,
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=temperature
        )

        if response.choices:
            return response.choices[0].text.strip()
        else:
            return "NO_COMPLETION"

    except openai.error.InvalidRequestError as e:
        print(f"Invalid request error: {e}")
        return "ERROR: InvalidRequest"

    except openai.error.AuthenticationError as e:
        print(f"Authentication error: {e}")
        return "ERROR: Authentication"

    except openai.error.APIConnectionError as e:
        print(f"API connection error: {e}")
        return "ERROR: APIConneection"

    except openai.error.OpenAIError as e:
        print(f"OpenAI error: {e}")
        return "ERROR: OpenAI"


# sample_prompts.shape
running_set = sample_prompts.sample(1000)
# running_set = sample_prompts[sample_prompts.hashed_prompt.isin(completed)]
for _, prompt in tqdm(running_set.iterrows(), total=running_set.shape[0]):
    save_completion_to_file_if_not_exists(f'../data/gpt_results/{prompt.hashed_prompt}.completion_temp_01', 
                               prompt.prompt)
# Out:
#   0%|                                 | 1/1000 [00:03<1:00:07,  3.61s/it]
# File '../data/gpt_results/db762b6a535973fb9750f1934f2c37ef.completion_temp_01' created and contents saved successfully.
#   0%|                                 | 2/1000 [00:08<1:13:03,  4.39s/it]
# File '../data/gpt_results/abe98ae1c92bd7ad41fc649405b9a7fc.completion_temp_01' created and contents saved successfully.
#   0%|                                 | 3/1000 [00:15<1:33:52,  5.65s/it]
# File '../data/gpt_results/dcdbec43602ac3d81793c32d33e5a77b.completion_temp_01' created and contents saved successfully.
#   0%|▏                                | 4/1000 [00:21<1:32:19,  5.56s/it]
# File '../data/gpt_results/c1df44ca037a53b1d14ba17b6eb58483.completion_temp_01' created and contents saved successfully.
#   0%|▏                                | 5/1000 [00:37<2:34:28,  9.32s/it]
# File '../data/gpt_results/c26d6653423ac877850a589eef1b1b47.completion_temp_01' created and contents saved successfully.

# %%
completed = glob('../data/gpt_results/*.completion_temp_07')
completed = [c.split('/')[-1].split('.')[0] for c in completed]

# %%
# import shutil 

# for c in completed:
#     shutil.move(f'../data/gpt_results/{c}.completion', f'../data/gpt_results/{c}.completion_temp_07')

# %%
import re

overall_pattern_1 = re.compile('^Learning [Oo]bjectives:(.*)Subject: (.*)Student [Ll]evel: (.*)', flags=re.DOTALL)
overall_pattern_2 = re.compile('^(1\..*)Subject: (.*)Student [Ll]evel: (.*)', flags=re.DOTALL)
split_los_pattern = re.compile('[0-9]+\.', re.DOTALL)

def parse_completion(c):
    segments = overall_pattern_1.findall(c)
    if len(segments) == 0:
        segments = overall_pattern_2.findall(c)
    if len(segments) > 0:
        learning_objectives = [lo.strip() 
                               for lo 
                               in re.split(split_los_pattern, segments[0][0].strip()) 
                               if lo.strip()]
        subject = segments[0][1].strip()
        level = segments[0][2].strip()
        return learning_objectives, subject, level
    else:
        return None

# %%
with open('../data/gpt_results/e361269fedf9f45642da1b0497fcb098.completion_temp_07') as f:
    completion = f.read()
print(completion)
parse_completion(completion)
# Out:
# 1. Describe the process of respiration in the human body
# 2. Explain the role of the lungs in the respiration process
# 3. Identify the role of oxygen and CO₂ in the body
# 4. Summarize the medical understanding of respiration
#
# Subject: Human Biology
# Student Level: Intermediate/Advanced
# (['Describe the process of respiration in the human body',
#   'Explain the role of the lungs in the respiration process',
#   'Identify the role of oxygen and CO₂ in the body',
#   'Summarize the medical understanding of respiration'],
#  'Human Biology',
#  'Intermediate/Advanced')

# %%
for c in completed:
    with open(f'../data/gpt_results/{c}.completion_temp_07') as f:
        completion = f.read()
    prompt = sample_prompts[sample_prompts.hashed_prompt == c]
    print("ID", c)
    print("Domain: ", prompt.domain.iloc[0])
    print("Year: ", prompt.year.iloc[0])
    print("Title: ", prompt.title.iloc[0])
    print("Description: ", prompt.desc.iloc[0])
    completion = parse_completion(completion)
    if completion:
        los, subject, level = completion
        print("Completion: ")
        print("-"*30)
        print("Learning Objectives:")
        for i, lo in enumerate(los):
            print(i, lo)
        print("Subject: ", subject)
        print("Level: ", level)
    else:
        print("UNPARSABLE COMPLETION:", completion)
    print("="*30)
# Out:
# ID 11c20f4567d5ca193395ced206023663
# Domain:  ja.coursera.org
# Year:  2021
# Title:  Comparing Genes, Proteins, and Genomes (Bioinformatics III)
# Description:  カリフォルニア大学サンディエゴ校による提供。Once we have sequenced genomes in the previous course, we would like to compare them to determine how species have evolved and ... 無料で登録。
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the fundamentals of gene and protein comparison.
# 1 Learn the principles of genomic comparison.
# 2 Analyze data from genome sequences.
# 3 Compare different genomes and proteins to identify evolutionary relationships.
# Subject:  Bioinformatics
# Level:  Advanced
# ==============================
# ID 918e206172e9088a7e73accaf4af9571
# Domain:  es.coursera.org
# Year:  2021
# Title:  Los obstáculos y la conducción en las negociaciones
# Description:  Ofrecido por Universidad Nacional Autónoma de México. En este curso se analizará para su aplicación la ubicación y señalamiento de los ... Inscríbete gratis.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Comprender los mecanismos de las negociaciones.
# 1 Explorar la ubicación y señalamiento de los obstáculos.
# 2 Analizar la importancia de la conducción en las negociaciones.
# 3 Aplicar la teoría a la práctica.
# Subject:  Negociación
# Level:  Universitario
# ==============================
# ID 35940e783db1d6b4e8bb463aa855d3f9
# Domain:  www.coursera.org
# Year:  2021
# Title:  TensorFlow for CNNs: Transfer Learning
# Description:  在 2 小时之内完成此指导项目。This guided project course is part of the "Tensorflow for Convolutional Neural Networks" series, and this series presents material that ...
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the fundamentals of transfer learning.
# 1 Use TensorFlow to apply transfer learning to a Convolutional Neural Network.
# 2 Utilize TensorFlow to build and train a CNN model.
# 3 Implement pre-trained models to solve a given problem.
# Subject:  Artificial Intelligence
# Level:  Beginner
# ==============================
# ID b657bfaec4859c081b17c7e679e4ecbd
# Domain:  zh.coursera.org
# Year:  2021
# Title:  iOS App Store & In-App Purchases
# Description:  由 LearnQuest 提供。This course teaches basics of monetization on iOS, starting with in-app ads and then moving to in-app purchases. You will learn more ... 免费注册。
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the fundamentals of monetizing iOS apps
# 1 Learn how to use in-app ads to increase revenue
# 2 Gain knowledge of in-app purchases and how to effectively implement them
# 3 Learn how to set up and manage an App Store account
# Subject:  iOS App Development
# Level:  Beginner to Intermediate
# ==============================
# ID 6c6b2b86301045c40ecb2d381e0d9377
# Domain:  ja.coursera.org
# Year:  2020
# Title:  Why Iowa? A Primer on Primaries and Caucuses Teach-Out
# Description:  The United States presidential election process is a complex one, spanning terms like “Super Tuesday,” delegates and incumbents, primaries and caucuses, and more.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the timeline of the presidential election process
# 1 Explain the differences between primaries and caucuses
# 2 Analyze the impact of Iowa on the presidential election process
# Subject:  Political Science
# Level:  High School/College
# ==============================
# ID d45d0507087672fecf64cf0705ef649c
# Domain:  www.edx.org
# Year:  2021
# Title:  Mechanik I
# Description:  Die Mechanik ist ein fundamentales Themengebiet aller Ingenieurwissenschaften. Lernen Sie die Grundprinzipien der Stereostatik und erlernen Sie die Fähigkeit mechanische Systeme zu analysieren.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Erlernen Sie die Grundprinzipien der Stereostatik
# 1 Erlernen Sie die Fähigkeit mechanische Systeme zu analysieren
# 2 Verstehen Sie die Anwendung der Grundprinzipien der Mechanik
# 3 Erlernen Sie die Anwendung der Mechanik auf verschiedene technische Bereiche
# Subject:  Ingenieurwissenschaften
# Level:  Anfänger bis Fortgeschrittene
# ==============================
# ID ffeec8def26e2b03411361cd1ffdce2e
# Domain:  es.coursera.org
# Year:  2021
# Title:  Learning, Knowledge, and Human Development
# Description:  Ofrecido por Universidad de Illinois en Urbana-Champaign. This course sets out to provide an understanding of theories of learning and ... Inscríbete gratis.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Analyze theories of learning and knowledge.
# 1 Understand the concept of human development.
# 2 Examine the relationship between learning, knowledge, and human development.
# 3 Analyze methods of measuring learning and development.
# Subject:  Educational Psychology
# Level:  Undergraduate
# ==============================
# ID e81de8016850221cec739eda215dcf1a
# Domain:  ru.coursera.org
# Year:  2020
# Title:  Ecosystems of California
# Description:  This course surveys the diversity, structure and functioning of California’s ecosystems through time and the ways they have influenced and responded to human activities and stewardship.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Identify and describe the variety of ecosystems found in California.
# 1 Understand the structure and functioning of California’s ecosystems.
# 2 Analyze the ways ecosystems have responded to human activity.
# 3 Describe the importance of environmental stewardship.
# Subject:  Ecology
# Level:  High School/College
# ==============================
# ID 614f4b90fb12c118da3c4f82ea064411
# Domain:  ja.coursera.org
# Year:  2020
# Title:  Strategic Business Management - Macroeconomics
# Description:  This course weds business strategy with the principles of macroeconomics.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Analyze economic data to make informed business decisions.
# 1 Understand the principles of macroeconomics and how they relate to business strategy.
# 2 Identify economic trends and their impact on business operations.
# 3 Develop strategies to manage macroeconomic risks.
# Subject:  Business Strategy
# Level:  Advanced
# ==============================
# ID 5ca23561ff249ebc66e6f888d6b82d23
# Domain:  www.edx.org
# Year:  2021
# Title:  Sparse Representations in Signal and Image Processing: Fundamentals
# Description:  <p>Learn about the field of sparse representations by understanding its fundamental theoretical and algorithmic foundations.</p>
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the theory behind sparse representations in signal and image processing.
# 1 Analyze algorithms used for sparse representations.
# 2 Utilize sparse representations to solve signal and image processing problems.
# Subject:  Signal and Image Processing
# Level:  Beginner to Intermediate
# ==============================
# ID 229a6c815590e6436e0ad304c22ecf4c
# Domain:  www.coursera.org
# Year:  2021
# Title:  Jet Fighters Game using Pygame
# Description:  Conclua este projeto guiado em menos de 2 horas. By the end of this project, you will create a fully functioning 2 player jet fighters game using Pygame in ...
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Configure the game environment in Pygame
# 1 Create a game loop that runs the game
# 2 Generate and display sprites
# 3 Incorporate user input to control game elements
# 4 Add sounds and other effects
# 5 Create a two-player game
# Subject:  Computer Science
# Level:  Beginner to Intermediate
# ==============================
# ID 7c6480d91327c23a398b3ebe602d5f47
# Domain:  www.coursera.org
# Year:  2021
# Title:  Write Professional Emails in English
# Description:  Offered by Georgia Institute of Technology. This is a course to help you write effective business emails in English. This course is unique ... Enroll for free.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the conventions and etiquette of writing professional emails in English.
# 1 Compose emails with a clear purpose and message.
# 2 Utilize correct spelling, grammar, and punctuation.
# 3 Craft emails that effectively communicate ideas.
# 4 Practice various email writing techniques.
# Subject:  Business English
# Level:  Beginner
# ==============================
# ID 00a437ac61145672b6eda50f6035f045
# Domain:  www.diziler.com
# Year:  2021
# Title:  Kore dizisi Good Doctor'un Amerikan uyarlaması The Good Doctor iddialı isimlerle geliyor!
# Description:  Bates Motel'ın yıldızı Freddie Highmore'un onay alması muhtemel yeni dizi projesi The Good Doctor'un oyuncu kadrosuyla ilgili haberler gelmeye başladı.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Explain the concept of American adaptations of Korean dramas.
# 1 Identify the main characters of The Good Doctor.
# 2 Analyze the potential success of The Good Doctor.
# 3 Compare the plot and themes of The Good Doctor to its Korean counterpart, Good Doctor.
# Subject:  Television and Film
# Level:  High School/College
# ==============================
# ID 6bcf96e2798e4e2b17d72f6b235cb922
# Domain:  ja.coursera.org
# Year:  2020
# Title:  A Circular Economy of Metals: Towards a Sustainable Societal Metabolism
# Description:  Metals are present everywhere around us and are one of the major materials upon which our economies are built.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Identify components of a circular economy of metals.
# 1 Analyze the role of metals in a sustainable societal metabolism.
# 2 Evaluate the environmental impacts of metal usage.
# 3 Examine the economic implications of a circular economy of metals.
# Subject:  Environmental Science
# Level:  College/University level.
# ==============================
# ID a4ae6bb1711503b5aaa0b132a1c777ed
# Domain:  es.coursera.org
# Year:  2021
# Title:  Agile и Scrum в работе над проектами и продуктами
# Description:  Этот вводный курс объясняет, как работать по Scrum, и дает полное понимание системы ценностей Agile. Agile-подходы бурно развиваются в ... Inscríbete gratis.
# UNPARSABLE COMPLETION: None
# ==============================
# ID 142ecb6fb81fc3efc1b22ecda6aa0692
# Domain:  es.coursera.org
# Year:  2021
# Title:  Creating a Team Culture of Continuous Learning
# Description:  Ofrecido por Universidad de Pensilvania. There is mounting concern that organizational groups and teams often fail to learn from their ... Inscríbete gratis.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Develop an understanding of team culture and its impact on learning.
# 1 Identify the benefits of continuous learning for teams.
# 2 Learn strategies for creating a team culture of continuous learning.
# 3 Identify methods for encouraging team members to share knowledge and expertise.
# Subject:  Organizational Learning
# Level:  Graduate/Professional
# ==============================
# ID c3cc470eb17dc6f7409d3ff50183c136
# Domain:  www.coursera.org
# Year:  2021
# Title:  Aprendizaje Automático con Python
# Description:  Offered by IBM. Este curso se sumerge en los conceptos básicos del aprendizaje automático mediante un lenguaje de programación accesible y ... Enroll for free.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Comprender los conceptos básicos del aprendizaje automático.
# 1 Aprender a usar el lenguaje de programación Python para implementar aprendizaje automático.
# 2 Aprender a evaluar y mejorar los resultados de aprendizaje automático.
# 3 Comprender los fundamentos de la programación orientada a objetos.
# Subject:  Aprendizaje Automático con Python
# Level:  Principiante a Intermedio
# ==============================
# ID 372908bf3efac1d48c478a95ff05be86
# Domain:  www.edx.org
# Year:  2021
# Title:  Basic Steps in Magnetic Resonance
# Description:  A MOOC to discover basic concepts and a wide range of intriguing applications of magnetic resonance to physics, chemistry, and biology
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the fundamental principles of magnetic resonance
# 1 Learn how to apply magnetic resonance to physics, chemistry and biology
# 2 Describe the range of applications of magnetic resonance
# 3 Develop the ability to create experiments in magnetic resonance
# Subject:  Magnetic Resonance
# Level:  Beginner
# ==============================
# ID fd279a7ccc2c74c2cec02b6245519ee5
# Domain:  www.coursera.org
# Year:  2021
# Title:  Building Test Automation Framework using Selenium and TestNG
# Description:  2시간 이내에 이 안내 프로젝트를 완료하세요. Selenium is one of the most widely used functional UI automation testing tools and TestNG is a brilliant testing framework.  Test ...
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the basics of Selenium and TestNG
# 1 Learn to design, develop, and maintain an automation framework
# 2 Be able to write and execute automated test scripts
# Subject:  Software Testing
# Level:  Intermediate
# ==============================
# ID 8d8e4931eb30dee52923c7d2f9aca85a
# Domain:  www.diziler.com
# Year:  2021
# Title:  Chris Wood, dizisi Supergirl hakkında konuştu
# Description:  Oyuncu Chris Wood, Mon-El ve Mxyzptlk arasındaki düşmanlığı ele aldı.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the rivalry between Mon-El and Mxyzptlk.
# 1 Analyze the character development of Mon-El and Mxyzptlk.
# 2 Critically assess the plot of the series Supergirl.
# Subject:  Media Studies
# Level:  Intermediate to Advanced
# ==============================
# ID 2005f8ff4da82ac955cba82bdef9910a
# Domain:  www.edx.org
# Year:  2021
# Title:  Introduction to RISC-V
# Description:  <p>Get to learn all about RISC-V: find out how to work with open specifications and the organization that curates them, and discover how you can become a part of this vibrant community.</p>
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the fundamentals of RISC-V architecture
# 1 Learn how to work with open specifications
# 2 Explore the organization that curates RISC-V
# 3 Discover how to become a part of the RISC-V community
# Subject:  Computer Science
# Level:  Intermediate to Advanced
# ==============================
# ID 2c19eea10189003c000cfaf969f69520
# Domain:  www.coursera.org
# Year:  2021
# Title:  Create and Format a Basic Document with LibreOffice Writer
# Description:  Complete this Guided Project in under 2 hours. In this project, you will create a new document from scratch using the basic features and functionality of ...
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Create a new document in LibreOffice Writer.
# 1 Format text, including fonts, size, and color.
# 2 Insert images and tables into a document.
# 3 Utilize basic features and functionality of LibreOffice Writer.
# Subject:  Office Software Applications
# Level:  Beginner
# ==============================
# ID db762b6a535973fb9750f1934f2c37ef
# Domain:  ja.coursera.org
# Year:  2020
# Title:  Forecasting, Budgeting, Territories, Evaluation and Legal/Ethical Issues
# Description:  In the fourth part of the Sales Operations/Management Specialization, students will explore the purpose and methods for forecasting and budgeting in a management role.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the purpose and methods of forecasting and budgeting in a management role.
# 1 Analyze and evaluate financial data to support decision-making in a sales organization.
# 2 Examine legal and ethical issues in a sales organization.
# 3 Analyze and create sales territories.
# Subject:  Sales Operations/Management
# Level:  Advanced
# ==============================
# ID e764b8e9c84d4361b2b75c1d8711d30f
# Domain:  www.edx.org
# Year:  2021
# Title:  Distribución: entrega de productos
# Description:  <p>Los procesos relacionados con el transporte abarcan desde la elección de las rutas hasta asegurar la recepción de las devoluciones. En este curso en línea conocerás el alcance de la distribución de productos para realizar una entrega de calidad y a tiempo.</p>
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Comprender la importancia de la distribución de productos para asegurar la entrega de calidad y a tiempo.
# 1 Aprender los procesos relacionados con el transporte para la distribución de productos.
# 2 Explorar los conceptos principales relacionados con la distribución y entrega de productos.
# Subject:  Logística y transporte
# Level:  Principiante
# ==============================
# ID ad1694c17159aab3b9c54ae8a14619c0
# Domain:  zh.coursera.org
# Year:  2021
# Title:  Introduction to Machine Learning in Sports Analytics
# Description:  由 密歇根大学 提供。In this course students will explore supervised machine learning techniques using the python scikit learn (sklearn) toolkit and real-world ... 免费注册。
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the basics of machine learning
# 1 Learn how to use the scikit-learn toolkit
# 2 Examine supervised machine learning techniques
# 3 Apply machine learning techniques to real-world sports analytics
# Subject:  Machine Learning
# Level:  Introduction (Beginner)
# ==============================
# ID e361269fedf9f45642da1b0497fcb098
# Domain:  www.edx.org
# Year:  2021
# Title:  Respiration in the Human Body
# Description:  <p>Learn about respiration and the function of the lungs, oxygen and CO₂ in the body from medical experts.</p>
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Describe the process of respiration in the human body
# 1 Explain the role of the lungs in the respiration process
# 2 Identify the role of oxygen and CO₂ in the body
# 3 Summarize the medical understanding of respiration
# Subject:  Human Biology
# Level:  Intermediate/Advanced
# ==============================
# ID c4d6b4425d44445196131a1278a9996d
# Domain:  www.edx.org
# Year:  2019
# Title:  å&#136;&#155;ä¸&#154;101: ä½ ç&#154;&#132;å®¢æ&#136;·æ&#152;¯è°&#129;ï¼&#159;
# Description:  å¦&#130;æ&#158;&#156;æ³¨å&#134;&#140;ã&#128;&#138;å&#136;&#155;ä¸&#154;101:è°&#129;æ&#152;¯ä½ ç&#154;&#132;å®¢æ&#136;·ï¼&#159;ã&#128;&#139;ç&#154;&#132;è®¤è¯&#129;è¯&#129;ä¹¦ï¼&#140;å¹¶ä¸&#148;é&#128;&#154;è¿&#135;è¯¾ç¨&#139;è&#128;&#131;æ ¸ï¼&#140;å°&#134;ä¼&#154;è&#142;·å¾&#151;æ&#156;&#137;æ&#149;&#136;æ&#156;&#159;ä¸º1å¹´ç&#154;&#132;ä»·å&#128;¼500ç¾&#142;é&#135;&#145;ç&#154;&#132;äº&#154;é©¬é&#128;&#138;äº&#145;æ&#156;&#141;å&#138;¡ä»£é&#135;&#145;å&#136;¸ã&#128;&#130;
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the basics of customer service
# 1 Learn how customer service is a key factor in business success
# 2 Develop customer service skills
# 3 Practice customer service techniques
# 4 Establish customer service policies and procedures
# Subject:  Customer Service
# Level:  Beginner
# ==============================
# ID 57ca96aca1e75efbbb0c9e591c27b31a
# Domain:  www.diziler.com
# Year:  2021
# Title:  Söz dizisi oyuncu kadrosu genişliyor
# Description:  Yakında Star TV’de ekrana gelmesi beklenen “Söz” dizisinin geniş oyuncu kadrosuna iki yeni ismin dahil olduğu duyuruldu.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Identify two new cast members of the upcoming TV show “Söz”.
# 1 Compare and contrast the roles of different cast members in the show.
# 2 Analyze the impact of additional cast members on the show’s plot.
# Subject:  Media Studies
# Level:  High School/Undergraduate
# ==============================
# ID 0618eebe699eec59e812df87976e812d
# Domain:  www.coursera.org
# Year:  2021
# Title:  Fundamentals of Finance
# Description:  由 宾夕法尼亚大学 提供。 In this course, you’ll learn the basic fundamentals of corporate finance. Based on the pre-term qualifying courses for Wharton MBA ... 免費註冊。
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the basic principles of corporate finance.
# 1 Develop an appreciation for the various components of corporate finance.
# 2 Analyze financial statements and use financial ratios to assess a company’s financial performance.
# 3 Learn how companies raise capital and make investment decisions.
# Subject:  Corporate Finance
# Level:  MBA
# ==============================
# ID 6eb18d97f4b4a07ed5f48f507d448702
# Domain:  zh.coursera.org
# Year:  2020
# Title:  The Future of Payment Technologies
# Description:  Discover the future of payment technology, from mobile payments to tokenization.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the different types of payment technologies, including mobile payments and tokenization.
# 1 Learn about the advantages and disadvantages of different payment technologies.
# 2 Explore the potential for future payment technologies.
# 3 Analyze the potential impact of payment technologies on businesses and consumers.
# Subject:  Payment Technologies
# Level:  Beginner to Intermediate
# ==============================
# ID 8dbf0a62de2cefa28238ce36c22e7489
# Domain:  pt.coursera.org
# Year:  2020
# Title:  Arranging for Songwriters
# Description:  You've created a song. You wrote the lyrics, decided on the melody, and maybe even recorded a simple demo.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Gain an understanding of basic music notation and song structure.
# 1 Learn techniques for arranging and producing a song.
# 2 Develop a skill set for creating a professional-sounding recording.
# Subject:  Music Theory/Songwriting
# Level:  Beginner to Intermediate
# ==============================
# ID 2ab3933cb06664af4cd7670fe0e0f9de
# Domain:  fr.coursera.org
# Year:  2021
# Title:  Lending, Crowdfunding, and Modern Investing
# Description:  Proposé par Université de Pennsylvanie. In this course, you’ll learn the foundational theories behind robo-advising, ... Inscrivez-vous gratuitement.
# Completion:
# ------------------------------
# Learning Objectives:
# 0 Understand the theories behind robo-advising
# 1 Gain an understanding of modern investing practices
# 2 Learn about different types of lending and crowdfunding
# 3 Evaluate the risks and rewards of modern investing
# 4 Utilize modern technology to maximize gains
# Subject:  Finance
# Level:  Beginner to Intermediate
# ==============================

# %%
another_running_set.hashed_prompt
# Out:
# 11473    4d392dbe11e2878db8748ef7e9f44660
# 29464    ed7b17233fc0204525fa1c5026aaf4f5
# 36749    8469308ef2a0f9c12d7d5eed9aecf1c5
# 11223    1abe305c2fbc960fba72285d1527c561
# 42760    0e96dce7ee44c2dddf0c401eb79930fd
# 37952    7bb7cad6c382d6da707c4aedb906eab5
# 35978    af27a045afa280b62f6c2f3de102be13
# 2396     f85c9217c6f1dc05fdfdcae11081feca
# 11986    3611ebe17e0d3330538e762f549f0219
# 38541    439da497dfce0444dd97868b07b523af
# Name: hashed_prompt, dtype: object

# %%
prompt_texts = set()
prompt_lengths = []

for _, prompt in sample_prompts.iterrows():
    prompt_text = prompt.prompt
    prompt_texts.add(prompt_text)
    prompt_lengths.append(len(prompt_text.split(' ')))

len(set(prompt_texts)), sum(prompt_lengths)
# Out:
# (9722, 820651)

# %%
prompt_texts
# Out:
# {'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Yalan Dünya\'nın yıldızı saç davasını kaybetti! Description: O dava sonuçlandı!"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Influencing: Storytelling, Change Management and Governance Description: The ability to influence without force or coercion is important in any organization and at all levels. Modern managers must master the art of persuasive communication, adapt to the needs of the audience, construct a good narrative and inspire the audience to act (Communicate with Impact). They must learn to design and negotiate both informal and complex agreements, and do this in diverse workplace cultures (Negotiate and Resolve Conflict).\n\nThe Specialization applies influencing methods in two areas of great importance: change management and risk governance. Successful change management eludes many individuals and organizations, so we propose a new approach to enable you to inspire and lead transformations (Manage Change). Similarly, in the post-financial crisis environment, many organizations acknowledge the need for effective risk governance but few, if any, have achieved it. We present evidence-based methods that will help your organization achieve its objectives (Engage the Board)."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: How to Write a Resume (Project-Centered Course) Description: 由 纽约州立大学纽约州立大学 提供。What you’ll achieve:  In this project-centered course*, you will craft an essential cornerstone of the modern-day job or internship ... 免费注册。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Steps in Japanese for Beginners1 Part1 Description: &lt;p&gt;Learn basic Japanese expressions to survive in Japanese.&lt;/p&gt;"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Soccer and Science Description: The course analyzes soccer from a new point of view, and combines the basic knowledge of soccer with the scientific theory it implicates. By taking this course, you\'ll gain knowledge about soccer and its scientific theory, and also develop a deeper appreciation for this unique sport.\r\n\r\n本课程将从全新 的视角剖析足球运动，将足球运动的基本知识和所蕴含的科学理论相结合，通过课程学习，掌握足球运动的相关知识和科学规律，欣赏足球运动独特的魅力。\r\n"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 10 Haziran 2016 Cuma reyting sonuçları Description: Hangi dizi ve yapımlar zirvede?"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Художественное проектирование сайта Description: От Санкт-Петербургский государственный университет. Курс посвящен проектированию сайта методами и средствами дизайна визуальных ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Russian for beginners А1. Русский язык: A1 Description: This specialization is aimed at learners who are interested in exploring the Russian language, and provides everything you need to start this journey. This specialization contains four courses, and begins with an introduction to the basics of the Russian alphabet and phonetics, which will be vital for you as you progress in your studies. All four courses provide extensive theoretical and practical materials, and supply listening, reading, and vocabulary exercises to enhance the learning process. Grammar materials will cover parts of speech, case system, verb conjugation, and sentence structure.\n\nUpon completion of the specialization, learners will be well-versed in the basic theories and rules of Russian phonetics and grammar; will acquire basic conversation vocabulary; be able to read simple texts; and hold conversation on everyday topics such as family, travel, hobbies, personal activities, and holidays.\n\nOur team is going to further improve and enrich the course materials to provide learners with up-to-date information, and to help them progress and achieve the best results."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Астрофизика: от звезд до границ Вселенной Description: Offered by Peter the Great St. Petersburg Polytechnic University. Этот курс посвящен ключевым проблемам современной астрофизики: рождению, ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Sparse Representations in Signal and Image Processing: Fundamentals Description: <p>Learn about the field of sparse representations by understanding its fundamental theoretical and algorithmic foundations.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Excel for Everyone: Core Foundations Description: <p>Learn Excel fundamentals including data wrangling, spreadsheet management, and basic data analysis.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 聆听的重要性 Description: 由 西北大学 提供。In this second MOOC in the Social Marketing Specialization - "The Importance of Listening" - you will go deep into the Big Data of social and ... 免费注册。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Intro to Programming With C#: Build A Word Guessing Game Description: このガイド付きプロジェクトは2時間以内に完了します。By the end of this project, you will create a  fully functioning Word Guessing game using C#. In this project, you will be able to ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Global Disease Masterclass: Global Disease Distribution Description: The Global Diseases Masterclass is part of the full-degree Masters of Public Health that the School of Public Health."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Practical Time Series Analysis Description: 由 纽约州立大学纽约州立大学 提供。 Welcome to Practical Time Series Analysis!  Many of us are "accidental" data analysts. We trained in the sciences, business, or ... 免費註冊。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: App Design and Development for iOS Description: In App Design and Development for iOS, the third course of the iOS App Development with Swift specialization, you will be developing foundational programming skills to support graphical element presentation and data manipulation from basic functions through to advanced processing."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Simulation Skills: This is Your Brain on the Future Description: Offered by Institute for the Future. Do you want to learn how to simulate the future more creatively and more effectively? This course is ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Homeland Security & Cybersecurity Connection - It\'s Not About the Terrorists Description: От Система университетов штата Колорадо. Welcome to Course 1 in CS4950, Homeland Security and Cybersecruity. In this course we ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Protecting Business Innovations via Trademark Description: Protecting Business Innovations Via Trademark\n\nWatch Course Overview:  https://youtu."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: iOS App Store & In-App Purchases Description: This course teaches basics of monetization on iOS, starting with in-app ads and then moving to in-app purchases."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Nutrición y obesidad: control de sobrepeso Description: Ofrecido por Universidad Nacional Autónoma de México. En este curso, ofrecido por la UNAM, reconocerás una herramienta para evitar, ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Russian Alphabet Description: Oferecido por Universidade Estadual de São PetersburgoUniversidade Estadual de São Petersburgo. Russian is considered to be one of ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: التأثير على الأشخاص Description: Proposé par Université du Michigan. ستعمل هذه الدورة التدريبية على تحسين قدرتك على التأثير على الأشخاص في المواقف التي لا يمكنك ... Inscrivez-vous gratuitement."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Thermodynamics Description: Introduction to basic concepts and applications of thermodynamics in mechanical engineering."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: The Language and Tools of Financial Analysis Description: Ofrecido por Universidad de Melbourne. In this course, participants will learn the foundations of accounting principles and financial ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Plato, Socrates, and the Birth of Western Philosophy | 西方哲学精神探源 Description: <p>Explore the works of Plato, Aristotle, Heraclitus and other originators of Western philosophy in an immersive study of ancient Greek and Roman philosophers. 本课程通过讲述古希腊罗马哲学家丰富的思想和观点，探讨西方哲学精神的起源，揭示西方民族的精神取向，阐明西方民族思维方式的特征。</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Procesamiento del lenguaje natural con Python y Power BI Description: Completa este Proyecto guiado en menos de 2 horas. Este proyecto es un curso práctico y efectivo para aprender acerca del Procesamiento Natural del ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Digital Marketing and Data Driven Analytics Description: <p><span lang="ES">Digital Marketing is the backbone element which uses platforms and digital technologies, such as any kind of device to maintain connected to the users. Once the users are part of this ecosystem, the companies convert this random data in accurate algorithms to improve the effectiveness of any marketing campaign.</span></p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Recruiting, Hiring, and Onboarding Employees Description: Oferecido por Universidade de MinnesotaUniversidade de Minnesota. Finding and hiring the right people is often cited as the number ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Teach English Now! Teaching Language Online Description: Whether you have already taught English as a Second Language and want to start teaching it online, you\'ve already been teaching ESL online and want to sharpen your skills, or you are new to teaching and interested in teaching ESL online, ASU and VOXY provide you with the basic ideas and concepts you need to know in order to successfully teach ESL online."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Интернет-маркетинг. Лидогенерация Description: Курс дает полное представление о ключевых инструментах онлайн-маркетинга. Курс подготовлен командой экспертов-практиков компании Ingate – одного из ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Survey Data Collection and Analytics Project (Capstone) Description: The Capstone Project offers qualified learners to the opportunity to apply their knowledge by analyzing and comparing multiple data sources on the ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: İclal Aydın, O Hayat Benim\'den ayrıldı! Description: FOX\'un sevilen dizisi O Hayat Benim\'de İclal Aydın, diziden ayrıldı."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Finding Purpose and Meaning In Life: Living for What Matters Most Description: Offered by University of Michigan. Welcome to Finding Purpose and Meaning in Life: Living for What Matters Most!   In this course, you’ll ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Israel State and Society  Description: Israel is a country that draws a lot of public attention around the globe."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: L’engagement efficace de la société civile dans le développement Description: 由 鹿特丹伊拉斯姆斯大学 提供。 Les organisations de la société civile (OSC) sont des acteurs clés du développement qui ont des contributions précieuses à apporter. ... 免費註冊。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Négocier avec succès : Stratégies et capacités essentielles Description: Proposé par Université du Michigan. We all negotiate on a daily basis. On a personal level, we negotiate with friends, family, ... Inscrivez-vous gratuitement."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Distributed Programming in Java Description: Oferecido por Universidade Rice. This course teaches learners (industry professionals and students) the fundamental concepts of ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Use Commands and Create a Remote Git Repository Description: このガイド付きプロジェクトは2時間以内に完了します。A key to maintaining a project under version control is to store it as a remote repository on a server that is backed up over ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Learn PHP Database Connectivity  Description: Terminez ce projet guidé en moins de 2 heures. In this 1.5-hours long project-based course, you will (Learn PHP database connectivity , Build Web pages with ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Introduction to Data Analysis Using Excel Description: ライス大学（Rice University）による提供。The use of Excel is widespread in the industry. It is a very powerful data analysis tool and almost all big and small ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Living with Dementia: Impact on Individuals, Caregivers, Communities and Societies Description: Health professionals and students, family caregivers, friends of and affected individuals, and others interested in learning about dementia and quality care will benefit from completing the course."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Python and Machine Learning for Asset Management  Description: This course will enable you mastering machine-learning approaches in the area of investment management."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Music Business Foundations Description: От Музыкальный колледж Беркли. This course has been developed to provide students with the latest instruction on the best way ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 26 Aralık 2016 Pazartesi reyting sonuçları Description: İçerde mi, Kırgın Çiçekler mi, Paramparça mı, Hangimiz Sevmedik mi, Bana Sevmeyi Anlat mı? Ekranlarda Pazartesi gününün galibi hangi yapım oldu?"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Универсальные практики влияния Description: Offered by National Research Tomsk State University. Знаете, с влиянием – как со здоровьем: мы не замечаем его, когда все в порядке, но ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Multiplatform Mobile App Development with React Native Description: This course focuses on developing truly cross-platform, native iOS and Android apps using React Native (Ver 0."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Asian Environmental Humanities: Landscapes in Transition Description: Offered by University of Zurich. In this course, featuring many researchers from the University of Zurich and international institutions, we ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Parallel Programming in Java Description: Oferecido por Universidade Rice. This course teaches learners (industry professionals and students) the fundamental concepts of ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: FPGA Capstone:  Building FPGA Projects Description: Ofrecido por Universidad de Colorado en Boulder. This course will give you hands-on FPGA design experience that uses all the concepts and ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: إدارة النظم وخدمات البنية التحتية لتكنولوجيا المعلومات Description: 由 Google 提供。ستنقلك هذه الدورة من العمل على جهاز كمبيوتر واحد إلى أسطول كامل. إدارة النظم هي مجال تكنولوجيا المعلومات المسؤول عن الحفاظ على وجود أنظمة ... 免费注册。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: eHealth: More than just an electronic record Description: The MOOC, "eHealth: More than just an electronic record!", is multidisciplinary in nature, and aims to equip the global audience of health clinicians, students, managers, administrators, and researchers to reflect on the overall impact of eHealth on the integration of care."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Aléatoire : une introduction aux probabilités - Partie 2 Description: エコール・ポリテクニーク（École Polytechnique）による提供。Ce cours d\'introduction aux probabilités a la même contenu que le cours de tronc commun de première année de ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Getting Started on Mainframe with z/OS Commands and Panels Description: 由 IBM 提供。Getting Started with the IBM Mainframe with z/OS Commands and Panels is a mostly hands-on in an IBM Mainframe z/OS Environment. A total of ... 免费注册。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Visualizing Data with Python Description: Data visualization is the graphical representation of data in order to interactively and efficiently convey insights to clients, customers, and stakeholders in general."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Inspiring and Motivating Arts and Culture Teams Description: Learn critical leadership skills that enable you to inspire and motivate individuals and teams, specifically in arts and culture organizations."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Electricity & Magnetism, Part 2 Description: PHYS 102.2x serves as an introduction to the magnetic field, how it is created by currents and magnetic materials, induction and inductors, and AC circuits."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Low Intermediate English: Help & Information Description: Offered by Voxy. In this course, you will learn important language for asking for help, giving and understanding directions, and sharing ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 遗传学实验 Description: 由 北京大学 ... 免费注册。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Understanding the Australian economy: An introduction to macroeconomic and financial policies Description: От Сиднейский университет. This four-week, four-module course explores selective aspects of the Australian economy, with ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Knowledge and Skills for Dementia Care: the SSLD Approach  Description: От Торонтский университет. This course is designed and produced by Professor Ka Tat Tsang of the Factor-Inwentash Faculty of ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Internet of Things V2: Setting up and Using Cloud Services Description: Have you wondered what exactly AWS is and why is it important?  Do you want to make informed design decisions about which services to use? Do you want to gain expertise to leverage the cloud for your own projects?\nIn this course, you will learn to interface with the AWS cloud."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Sustainable Urban Environments Description: Learn how integrated systems and individual actions can shape sustainable cities, generating higher quality of life for the future."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 工程圖學 3D CAD 專題 Description: От Национальный университет Тайваня. 想讓自己3D建模功力大增？想了解3D建築模型的繪製過程？ 「工程圖學3D CAD專題」延續前一門課「工程圖學3D ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title:  Explorando seu microbioma Description: Imagine if there were an organ in your body that weighed as much as your brain, that affected your health, your weight, and even your behavior."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Corporate Entrepreneurship: Innovating within Corporations Description: For an increasing number of established companies, creating new business opportunities within the company is an imperative for success. Maturing technologies and aging product portfolios are requiring companies to create, develop, and sustain innovative new businesses. The Corporate Entrepreneurship Specialization is designed for those interested in learning how to innovate and apply entrepreneurship principles in the corporate setting.\n\nLearners will develop knowledge on how to navigate the barriers to creating, developing, and sustaining innovative new businesses or initiatives within existing companies. These new activities rarely fit neatly within well-established systems, processes, and cultures. Learners will develop the skills, and learn the tools and best practices, for identifying and developing the entrepreneurial opportunities, building business models, creating strategies for leading innovation, and financing innovation. These four topics comprise the four courses of the Corporate Entrepreneurship Specialization, along with a final project.\n\nThe Corporate Entrepreneurship Specialization is for individuals who are charged and/or inspired to develop and lead new businesses within established companies. It\'s specifically designed for junior- and middle-managers with the the opportunity, or responsibility, to start new businesses or initiatives within their company or division, in any industry, and in any country."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Insurance Reserving, Risk Management and Analysis of Key Performance and Financial Indicators Description: <p>Learn the key performance and financial indicators that will allow you to analyze and value an insurance company.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Japanese for beginners 1 Description: Proposé par Université d\'État de Saint-Pétersbourg. Japanese language has become extremely popular among learners in recent ... Inscrivez-vous gratuitement."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Implementar um AWS EKS Cluster e uma Web App usando EKSCTL Description: Schließen Sie dieses geführte Projekt in weniger als 2 Stunden ab. Neste projeto de duas horas, você aprenderá como usar a ferramenta de linha de comando ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: The Piano Sonata: Origins to Mozart Description: Proposé par Université du Michigan. In this course, you’ll be introduced to sonata form; how it works, where it came from, and ... Inscrivez-vous gratuitement."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Copyright for Multimedia Description: Copyright questions about different formats (data, images, music and video) can be especially difficult."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Understanding Violence Description: We are so pleased to have you join us as we investigate this crucial topic."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Understanding Modern Finance Description: This Specialization is designed for a wide audience of those interested in finance either professionally or just of curiosity, including managers of different levels specializing in finance, accounting, business planning, strategy, consulting, and project management, IT specialists engaged in the area of finance, fin-tech, big data, and valuation, etc.\n\nThrough four courses and the final Project, you will cover the theory and practice of capital markets and financial institutions, corporate finance and project valuation, financial and managerial accounting as applied to finance, as well as the M&A market as the ultimate judge of financial efficiency and value creation.\n\nThe Specialization will prepare you to understand and use the applications of financial ideas, concepts, models, strategies, and tools to build a successful career in finance and in business, as well as to take advantage of opportunities offered by financial markets."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Developing a Connect Four Game using Java OOP Description: Complete this Guided Project in under 2 hours. In this 1-hour long project-based course, you will learn how to create a connect four console game using ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: TRT radyoları gelirleriyle de zirvede! Description: TRT Radyolarının tarihinde ilk kez, reklam gelirleri giderlerinin üzerine çıktı."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Scienza delle costruzioni Description: <p>Il corso si propone di illustrare i fondamenti teorici e gli aspetti applicativi della Meccanica delle Strutture</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Sample-based Learning Methods Description: In this course, you will learn about several algorithms that can learn near optimal policies based on trial and error interaction with the environment---learning from the agent’s own experience."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Disability Inclusion in Education: Building Systems of Support  Description: Worldwide millions of children are not able to fully participate in schooling, and this is especially a problem for children with disabilities."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Producción y consumo responsable: ODS 12 Description: <p>Aprende las formas de producir y consumir sanamente a partir de un enfoque agroecológico, contribuyendo así al cuidado del planeta. Este curso en línea se enfoca en el objetivo número 12 de los Objetivos de Desarrollo Sostenible de las Naciones Unidas.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Leading Healthcare Quality and Safety Description: Ensuring patient safety and healthcare quality is critical and should be a key focus of everyone in healthcare practice."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: AfricaLive! - Entrepreneurship in Emerging Economies Description: <p>Learn about the opportunities for entrepreneurship in Africa that are focused on solving the continent’s core problems.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Optimizing Diversity on Teams Description: Oferecido por Universidade da Pensilvânia. By drawing on social science perspectives, this course enables you to learn what ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Inequality and Democracy Description: Ofrecido por Universidad de Utrecht. Most countries are getting more and more unequal. But the core of democracy is political equality: ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Математика и Python для анализа данных Description: Анализ данных и машинное обучение существенно опираются на результаты из математического анализа, линейной алгебры, методов оптимизации, теории ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Célula Solar Orgânica: Teoria e Prática Description: Oferecido por Universidade Técnica da Dinamarca (DTU). The goal of the course is to give students awareness of the largest ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Italian Language and Culture: Beginner (2019-2020) Description: <p>Learn the basics of the Italian language and culture through videos, podcasts, interviews, and much more.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Fase final de Marketing en redes sociales de Facebook Description: От Facebook. En este curso final, practicarás la creación de una presentación sobre la campaña de marketing que has ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: The Critical Role of IT Support Staff in Healthcare Description: Offered by Johns Hopkins University. This is a very exciting time to be exploring a career in Health IT Support! In this introductory ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Poyraz Karayel 82. bölüm final fragmanında veda! Description: Poyraz Karayel bu akşam yayınlanacak 82. final bölümünde hüzünlü ve heyecan dolu bir vedaya imza atacak. Detaylar haberimizde!"""\n\n    Learning objectives, subject and student level:',
# ...
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Understanding the Business Environment Description: <p>An introduction to the business environment.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Foundations of Sports Analytics: Data, Representation, and Models in Sports Description: 由 密歇根大学 提供。This course provides an introduction to using Python to analyze team performance in sports. Learners will discover a variety of techniques ... 免费注册。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Introdução à Economia do Trabalho: Teorias e Políticas Description: От Государственный университет Кампинас. O Curso é uma iniciativa pioneira do Centro de Estudos Sindicais e de Economia do ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Power\'dan Starz kanalı için rekor! Description: Power 3. sezon bomba gibi başladı..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Developing Cloud Apps with Node.js and React Description: Ofrecido por IBM. In this course, you will focus on server-side JavaScript and frameworks. You will discover ways to make development ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Probability - The Science of Uncertainty and Data Description: <p>Build foundational knowledge of data science with this introduction to probabilistic models, including random processes and the basic elements of statistical inference -- <em>Part of the MITx MicroMasters program in Statistics and Data Science.</em></p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Connect Your Services with Microsoft Azure Service Bus Description: Oferecido por Microsoft. Azure lets you create applications composed of various components: website front-ends, back-end services, ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Managing Asthma, Allergies, Diabetes, and Seizures in School Description: Welcome to School Health specialization: Managing Asthma, Anaphylaxis, Food Allergies, Diabetes, and Seizures in School course."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Analyze Datasets and Train ML Models using AutoML Description: In the first course of the Practical Data Science Specialization, you will learn foundational concepts for exploratory data ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: ART of the MOOC: Activismo y Movimientos Sociales Description: Este curso es para activistas, artistas y pensadores que deseen entender mejor el cambio social y participar en él. El contenido del curso ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Protecting Business Innovations via Trademark Description: Proposé par Université des sciences et technologies de Hong Kong. Protecting Business Innovations Via Trademark  Watch Course ... Inscrivez-vous gratuitement."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Promotional Materials Every Musician Needs Description: コロラド大学ボルダー校（University of Colorado Boulder）による提供。They say that first impressions are the strongest, and that is definitely true in the arts! The ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Global Environmental Management Description: Ofrecido por Universidad Técnica de Dinamarca (DTU). Learn about the best environmental technologies for a sustainable development and how ... Inscríbete gratis."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Análisis de documentos con servicios cognitivos de Azure Description: Completa este Proyecto guiado en menos de 2 horas. En este proyecto de 1 hora, aprenderás a desarrollar modelos no supervisados con uno de los servicios ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Copyright for Educators & Librarians Description: Fear and uncertainty about copyright law often plagues educators and sometimes prevents creative teaching.  This course is a professional ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 22 Eylül 2016 Perşembe reyting sonuçları Description: Yüksek Sosyete mi, Bodrum Masalı mı, Asla Vazgeçmem mi, Yeter mi, Kördüğüm mü? Ekranlarda Perşembe gününün galibi hangi yapım oldu?"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Linear Regression with Python Description: このガイド付きプロジェクトは2時間以内に完了します。In this 2-hour long project-based course, you will learn how to implement Linear Regression using Python and Numpy. Linear ..."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Manage Resources in Azure Description: Oferecido por Microsoft. In this course, you will learn how to work with the Azure command line and web portal to create, manage, ... Inscreva-se gratuitamente."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: VR and 360 Video Production Description: Welcome to the Google AR & VR Virtual Reality and 360 video production course! Our mission is to give you the skills you need to get started with your first VR project."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Introduction to Breast Cancer Description: Proposé par Université Yale. Welcome to an Introduction to Breast Cancer!  In this course, we’ll learn a bit about the leading ... Inscrivez-vous gratuitement."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Lending, Crowdfunding, and Modern Investing Description: In this course, you’ll learn the foundational theories behind robo-advising, crowdfunding, and marketplace lending, and how to apply these theories to optimize your investments."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Digital Thread: Components Description: This course will help you recognize how the "digital thread" is the backbone of the digital manufacturing and design (DM&D) transformation, turning manufacturing processes from paper-based to digital-based."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Chinese for HSK 6 Description: HSK六级课程旨在通过学习HSK六级相关内容提高学习者的汉语水平，并帮助学习者在HSK六级考试中获得好成绩。\nHSK六级慕课课程共12周，分为两个部分。\n第一部分：汉语知识与技能课。侧重于教六级水平的汉语语言知识，训练表达技能，以HSK真题等为材料，由四位教师分别从听力、语法词汇、阅读和写作几个方面展开教学。学时共8周，每周有5个视频，每个视频的时长约10分钟。每次课后有若干练习题，每周有一次小考。\n第二部分：HSK考试指导课。侧重于提高学习者适应HSK六级考试的能力，由上述四位教师分别围绕听力、阅读和写作三项考试展开教学。学时共4周，每周有五个视频，每个视频的时长约10分钟。每次课后有若干练习题，最后有一次模拟考试。\n学习者完成全部课程并进行了考试，成绩（包括小考和模拟考试成绩）达到课程要求（60分及格）就可以具备得到本课程证书的基本条件。关于获得课程证书的其它要求请看Coursera的有关规定。"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Accounting and Finance for IT professionals Description: This course presents an introduction to the basics of financial accounting and finance for IT professionals."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Vatanım Sensin 14. bölüm fragmanında Mustafa Kemal\'in mektubu Description: Her bölüm ayrı bir heyecana ev sahipliği yapan Vatanım Sensin yarın akşam 14. bölümüyle ekranlarda yerini alacak. Vatanım Sensin dizisinin nefes kesici sahnelere sahip 14. bölüm fragmanlarına Mustafa Kemal\'ın çağrısı damga vurdu."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Теория игр Description: От Московский физико-технический институт. Разработанный МФТИ курс отличается тем, что все основные конструкции и принципы ... Зарегистрироваться бесплатно."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Estimating ML-Models Financial Impact Description: HSE 대학에서 제공합니다. This course covers the basics of financial impact estimation for machine learning models deployed in business processes. We will ... 무료로 등록하십시오."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Understanding Modern Physics II: Quantum Mechanics and Atoms Description: Offered by The Hong Kong University of Science and Technology. Course Overview: https://youtu.be/xyF-MmGNxd0  The 20th century was known as ... Enroll for free."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Energy Subsidy Reform Description: <p>A course on energy subsidies, their costs, and the design of a successful reform based on country case studies.</p>"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Google Cloud Platform Fundamentals: Core Infrastructure em Português Brasileiro Description: Este curso é uma apresentação da terminologia e dos conceitos importantes para trabalhar com o Google Cloud Platform (GCP)."""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: 18 Şubat 2017 Cumartesi reyting sonuçları Description: Kalbimdeki Deniz mi, Adı Efsane mi, İçimdeki Fırtına mı, Seksenler mi? Ekranlarda Cumartesi gününün galibi hangi program oldu?"""\n\n    Learning objectives, subject and student level:',
#  'The following text is the title and description of a course. Give me a list of learning objectives of the course, the subject the course belogs to and what level of student it is appropriate for.\n\n    Text: """Title: Российское предпринимательское право Description: HSE Universityによる提供。Современное российское предпринимательское право ориентировано на использование частноправовых и публично-правовых принципов и ... 無料で登録。"""\n\n    Learning objectives, subject and student level:',
#  ...}

# %%
17 / 50
# Out:
# 0.34

# %%
title_descs_sample.title.iloc[0]
# Out:
# 'Grow Your Business with Goldman Sachs 10,000 Women'

# %%
[(f, df[df.p.str.contains('description')].o.value_counts()) 
 for (f, df) 
 in top_ed_data]
# Out:
# [('../data/processed/pld_data/ja_coursera_org_2020.csv',
#   The Foundations of Teaching for Learning programme is for anyone who is teaching, or who would like to teach, in any subject and any context - be it at school, at home or in the workplace.                                                                                                                                                                              10
#   Este curso es uno de los 10 cursos disponibles en la colección Goldman Sachs 10,000 Women, diseñado para emprendedoras listas para llevar su negocio al siguiente nivel.                                                                                                                                                                                                   9
#   Prove to potential employers that you’re up to the task by becoming an Autodesk Certified Professional.                                                                                                                                                                                                                                                                    7
#   Este é um dos 10 cursos disponíveis na coleção do 10,000 Women da Goldman Sachs, concebida para empreendedoras prontas para levarem seus negócios ao próximo nível.                                                                                                                                                                                                        6
#   Bienvenue dans cette formation sur l'art et la science du machine learning.                                                                                                                                                                                                                                                                                                5
#                                                                                                                                                                                                                                                                                                                                                                             ..
#   Once you have a prototype and a clearer vision of the opportunity, you’ll need to create a small organization to discover how to create a repeatable and scalable business model.                                                                                                                                                                                          1
#   In this course, we trace the evolution of networks and identify the key concepts and functions that form the basis for layered architecture.                                                                                                                                                                                                                               1
#   Il s’agit d’un MOOC sur la crise internationale sur Ebola partie d’Afrique de l’Ouest en 2014 ; d’une durée de 5 semaines, où interviendront plus de 30 professeurs des universités, chercheurs, responsables politiques, autorités sanitaires nationales et internationales, membres d’ONGs, et autres acteurs d’Europe et d’Afrique sur plus de 60 séquences vidéos.     1
#   In this course, you will analyze and apply essential design principles to your Tableau visualizations.                                                                                                                                                                                                                                                                     1
#   Learners will present a well-organized academic speech on a topic in an academic field of the learner's choice.                                                                                                                                                                                                                                                            1
#   Name: o, Length: 1919, dtype: int64),
#  ('../data/processed/pld_data/fr_coursera_org_2020.csv',
#   This course provides an analytical framework to help you evaluate key problems in a structured fashion and will equip you with tools to better manage the uncertainties that pervade and complicate business processes.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        5
#   Les deux principaux composants de tout pipeline de données sont les lacs de données et les entrepôts de données.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               5
#   En este curso acelerado a pedido, se brinda a los participantes una introducción a los servicios de infraestructura y plataforma flexibles y completos que proporciona Google Cloud Platform.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  4
#   何謂「食品安全」?\n\n目前食品安全相關議題儼然已經成為我國學術研究、媒體關注的顯學。所謂食品安全可從兩方面觀察，一方面是傳統意義之安全，即現在現有科技與環境條件之基礎上，人類已經認識並得到公示之安全界定；另一方面，伴隨科學發展與技術進步，當人類認識又提高一個層次而對安全性提出新要求時，必須重新界定看似安全但卻存在值得研究之問題，如補充維生素對人體作用之爭議、油炸食品對健康之影響等。\n\n何謂「風險分析」?\n\n食品科技日新月異，人類對飲食條件日益增高，如麵條口感必須Q彈、茶飲料要有回甘喉韻，食品業者為添增食品風味，在食品製造過程中，往往摻入較以往更加繁雜且多樣化之技術或添加物，在滿足消費者味蕾同時，也帶來諸多食品安全之相關風險。伴隨科技逐漸蓬勃與行銷全球化之趨勢，食品科學領域因而蘊含更多對健康俱為之隱憂之不確定性，行政管制於新興風險社會下面臨前所未見的挑戰，傳統「危險防止」的國家任務被要求提升至「風險預防」。因此，在現今食安事件一再發生，而污染源又極為多元的情況下，與食品安全相關之風險管理措施，已經逐漸受到世界各國之關注，許多國家紛紛透過立法及建立專責機構，強化對現代食品之監督管理。\n\n風險分析其實是進入食品安全生活以及保障我們安全最重要的一個課題，延續過去在食品安全與毒理的概念並加入風險分析的架構，制定一套完整的食品安全系統：以科學為基礎，制定政策上的管理，同時應該公開積極與大眾溝通。食品安全資訊需要客觀的安全和主觀的安心並存，安全是科學、安心是人性，中間的轉換需要消費者、媒體、政府和食品界一起努力，花時間改善。\n食品安全與風險分析蘊藏著哪些箇中奧妙，讓我們一起跟隨著姜老師的腳步，一探究竟！    4
#   This six-module program, developed by Google, will train you to be a Certificated Professional Installer (CPI) of radios which utilize the Citizens Broadband Radio Service (CBRS) band to provide communications infrastructure.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              4
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ..
#   透過個案故事和邏輯推演，帶領學生認識賽局理論的核心觀念，幫助學生建立一套完整實用的策略思考架構，並將之應用在各種商業決策，包括產品企劃、定價、談判、行銷、銷售與人際溝通。這門課和其他所有賽局理論課程不同，沒有數學、不討論理論模型，而是把學生帶入歷史上不同經理人所曾經面對的決策情境。                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
#   How are international power relations changing and how can global peace and stability be maintained? This course familiarizes you with some main theories of international relations, shows how the global order is gradually changing and discusses how selected international and regional organizations contribute to the maintenance of global peace and security.                                                                                                                                                                                                                                                                                                                                                                         1
#   Welcome to the Cloud Computing Applications course, the second part of a two-course series designed to give you a comprehensive view on the world of Cloud Computing and Big Data!\n\nIn this second course we continue Cloud Computing Applications by exploring how the Cloud opens up data analytics of huge volumes of data that are static or streamed at high velocity and represent an enormous variety of information.                                                                                                                                                                                                                                                                                                                 1
#   In this first course of The Pronunciation of American English specialization, you will learn and practice all of the consonant sounds of American English, including some pairs of consonants that are especially tricky.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
#   This Innovation and Entrepreneurship course focuses on the interconnection between entrepreneurial thinking and innovation.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
#   Name: o, Length: 1451, dtype: int64),
#  ('../data/processed/pld_data/ru_coursera_org_2020.csv',
#   Este curso es uno de los 10 cursos disponibles en la colección Goldman Sachs 10,000 Women, diseñado para emprendedoras listas para llevar su negocio al siguiente nivel.                                                                                                                                                                    7
#   Este é um dos 10 cursos disponíveis na coleção do 10,000 Women da Goldman Sachs, concebida para empreendedoras prontas para levarem seus negócios ao próximo nível.                                                                                                                                                                         7
#   This accelerated on-demand course introduces participants to the comprehensive and flexible infrastructure and platform services provided by Google Cloud with a focus on Compute Engine.                                                                                                                                                   6
#   There are over 100 million horses, donkeys and mules in the world today and owners of these animals can be found on almost every continent and in almost every society.                                                                                                                                                                     5
#   Optimization is a common form of decision making, and is ubiquitous in our society.                                                                                                                                                                                                                                                         4
#                                                                                                                                                                                                                                                                                                                                              ..
#   The past 15 years have been exciting ones in plant biology. Hundreds of plant genomes have been sequenced, RNA-seq has enabled transcriptome-wide expression profiling, and a proliferation of "-seq"-based methods has permitted protein-protein and protein-DNA interactions to be determined cheaply and in a high-throughput manner.    1
#   Critical thinking – the application of scientific methods and logical reasoning to problems and decisions – is the foundation of effective problem solving and decision making.                                                                                                                                                             1
#   وسوف تستخدم هذه الدورة منهجية غير فنية لتحليل الكيفية التي تستخدم بها الحكومات السياسة من أجل التأثير على الاقتصاد في الدولة.                                                                                                                                                                                                               1
#   This course introduces classes, instances, and inheritance. You will learn how to use classes to represent data in concise and natural ways.                                                                                                                                                                                                1
#   You live a hands-on-life, and you intend continuing doing so! That is why I guess you already have checked where the QR-code (the logo) for this course lead to, right?\n\nAnd it is in such kind of setting you prefer hands-on-learning.                                                                                                  1
#   Name: o, Length: 1386, dtype: int64),
#  ('../data/processed/pld_data/www_coursera_org_2020.csv',
#   In this course you will engage in a series of challenges designed to increase your own happiness and build more productive habits.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  46
#   What is machine learning, and what kinds of problems can it solve? What are the five phases of converting a candidate use case to be driven by machine learning, and why is it important that the phases not be skipped? Why are neural networks so popular now? How can you set up a supervised learning problem and find a good, generalizable solution using gradient descent and a thoughtful way of creating datasets? Learn how to write distributed machine learning models that scale in Tensorflow, scale out the training of those models. and offer high-performance predictions. Convert raw data to features in a way that allows ML to learn important characteristics from the data and bring human insight to bear on the problem. Finally, learn how to incorporate the right mix of parameters that yields accurate, generalized models and knowledge of the theory to solve specific types of ML problems. You will experiment with end-to-end ML, starting from building an ML-focused strategy and progressing into model training, optimization, and productionalization with hands-on labs using Google Cloud Platform.\n\n> By enrolling in this specialization you agree to the Qwiklabs Terms of Service as set out in the FAQ and located at: https://qwiklabs.com/terms_of_service <    21
#   Design modern switched-mode power converters; create high-performance control loops around power converters; understand efficiency, power density and cost trade-offs\n\nBy 2030, 80% of all electrical energy will be processed by power electronics. Professional advantages continue to grow for technical engineers who understand the fundamental principles and technical requirements of modern power conversion systems. This specialization covers design-oriented analysis, modeling and simulation techniques leading to practical engineering of high-performance power electronics systems.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            20
#   Ask the right questions, manipulate data sets, and create visualizations to communicate results.\n\nThis Specialization covers the concepts and tools you'll need throughout the entire data science pipeline, from asking the right kinds of questions to making inferences and publishing results. In the final Capstone Project, you’ll apply the skills learned by building a data product using real-world data. At completion, students will have a portfolio demonstrating their mastery of the material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    15
#   If you want to break into AI, this Specialization will help you do so. Deep Learning is one of the most highly sought after skills in tech. We will help you become good at Deep Learning.\n\nIn five courses, you will learn the foundations of Deep Learning, understand how to build neural networks, and learn how to lead successful machine learning projects. You will learn about Convolutional networks, RNNs, LSTM, Adam, Dropout, BatchNorm, Xavier/He initialization, and more. You will work on case studies from healthcare, autonomous driving, sign language reading, music generation, and natural language processing. You will master not only the theory, but also see how it is applied in industry. You will practice all these ideas in Python and in TensorFlow, which we will teach.\n\nYou will also hear from many top leaders in Deep Learning, who will share with you their personal stories and give you career advice.\n\nAI is transforming multiple industries. After finishing this specialization, you will likely find creative ways to apply it to your work.\n\nWe will help you master Deep Learning, understand how to apply it, and build a career in AI.                                                                                                                 15
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ..
#   全球卫生导论回顾了全球范围内公共卫生发展的各个历史时期令人关注及其影响重大的事件，介绍公共卫生、国际卫生和全球卫生等相关概念和背景，阐述全球疾病负担、健康决定因素、主要健康问题及其应对策略，剖析目前全球关注的影响健康的主要卫生问题，从群体的层面的因素分析到个体层面的行为指导，分析社会发展、卫生系统、公共政策和全球合作对人群健康状况的决定作用。\n全球卫生以提高全球范围内的健康水平、实现全球健康公平为宗旨，重点关注超越国界的健康问题、健康决定因素和解决方案，涉及医学领域内外的多学科，提倡不同学科间的通力合作和人群预防与临床治疗的综合，同等对待不同地域、不同经济水平、不同的种族的所有人群。作为一门普适型的全球卫生导论课，旨在使不同学科和专业领域的学习者能了解全球卫生的历史和相关概念，熟悉全球疾病负担、健康决定因素、主要健康问题和全球应对策略。\n课程内容包括全球卫生概述、卫生系统与筹资、全球疾病负担、环境与健康、营养/生活方式与健康、妇幼保健与生殖健康、耐药结核病流行与控制、艾滋病的流行与控制、老龄化与慢性病防治、突发公共卫生事件应对等。\n授课团队由复旦大学公共卫生学院各二级学科的带头人和资深教授组成。本课程期望能引起不同学科的学生对全球健康问题的关注，激发其致力于探究健康相关问题的兴趣，引导其分析健康问题的社会决定因素，赋予其用合力解决全球健康问题的理念。                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
#   The world is urbanizing fast. In less than a century more than 1 billion people have been urbanized.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
#   Do you have data and wonder what it can tell you?  Do you need a deeper understanding of the core ways in which machine learning can improve your business?  Do you want to be able to converse with specialists about anything from regression and classification to deep learning and recommender systems?\n\nIn this course, you will get hands-on experience with machine learning from a series of practical case-studies.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
#   Welcome!\nDo you wish to know how to analyze and solve business and economic questions with data analysis tools? Then Econometrics by Erasmus University Rotterdam is the right course for you, as you learn how to translate data into models to make forecasts and to support decision making.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
#   The course examines specific strategies for community organizing for social justice in a diverse, democratic society.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
#   Name: o, Length: 2564, dtype: int64),
#  ('../data/processed/pld_data/es_coursera_org_2020.csv',
#   This course is one of 10 courses available in the Goldman Sachs 10,000 Women collection, designed for entrepreneurs ready to take their business to the next level.         10
#   Este curso te hará pasar de trabajar en una sola computadora a una flota completa.                                                                                           5
#   Este curso es uno de los 10 cursos disponibles en la colección Goldman Sachs 10,000 Women, diseñado para emprendedoras listas para llevar su negocio al siguiente nivel.     5
#   Apresentaremos o TensorFlow de baixo nível e trabalharemos com os conceitos e APIs necessários para gravar modelos de aprendizado de máquina distribuídos.                   5
#   This lesson is part of a full course, Speak English Professionally: In Person, Online & On the Phone.                                                                        5
#                                                                                                                                                                               ..
#   La incorporación del aprendizaje automático a las canalizaciones de datos aumenta la capacidad de las empresas de extraer estadísticas de sus datos.                         1
#   This course will cover the basic elements of designing and evaluating questionnaires.                                                                                        1
#   La planeación estratégica es una metodología de gran impacto que ha demostrado su eficacia en las mejores empresas del mundo.                                                1
#   Este curso te enseñará cómo crear chatbots útiles sin la necesidad de escribir ningún código.                                                                                1
#   Kursus ini membekali peserta kemampuan untuk membangun solusi yang sangat andal dan efisien di Google Cloud menggunakan pola desain yang terjamin.                           1
#   Name: o, Length: 1332, dtype: int64),
#  ('../data/processed/pld_data/pt_coursera_org_2020.csv',
#   This course is one of 10 courses available in the Goldman Sachs 10,000 Women collection, designed for entrepreneurs ready to take their business to the next level.                                                                                                                              8
#   Este curso es uno de los 10 cursos disponibles en la colección Goldman Sachs 10,000 Women, diseñado para emprendedoras listas para llevar su negocio al siguiente nivel.                                                                                                                         7
#   This self-paced training course gives participants broad study of security controls and techniques on Google Cloud Platform.                                                                                                                                                                     7
#   If you are a software developer who wants to build scalable AI-powered algorithms, you need to understand how to use the tools to build them.                                                                                                                                                    6
#   This accelerated on-demand course introduces participants to the comprehensive and flexible infrastructure and platform services provided by Google Cloud with a focus on Compute Engine.                                                                                                        6
#                                                                                                                                                                                                                                                                                                   ..
#   Tú y yo, al igual que la mayoría de personas, con las acciones que realizamos tenemos el propósito de mejorar las circunstancias en las que viven las personas.                                                                                                                                  1
#   Наглядно – интересно – просто – понятно!\nДанный курс представляет собой серию физических опытов, в которых наглядно объясняются основные законы волновой оптики.                                                                                                                                1
#   In this course, you will learn what an argument is. The definition of argument will enable you to identify when speakers are giving arguments and when they are not.                                                                                                                             1
#   Learn about the impact of infectious disease on sustainable animal-based food production by understanding the science of growth, immunity, and infection and by learning the problem-solving skills needed to advance animal health and food production through optimal management practices.    1
#   Have you wondered how huge software projects, like the Google search engine, are developed?  \n\nIn this course, you’ll move beyond coding in the “main” method to learn to design and build more complex Java software projects (though not quite as complex as the Google search engine!).     1
#   Name: o, Length: 1826, dtype: int64),
#  ('../data/processed/pld_data/zh_coursera_org_2020.csv',
#   This course is one of 10 courses available in the Goldman Sachs 10,000 Women collection, designed for entrepreneurs ready to take their business to the next level.                                                                                   7
#   The Foundations of Teaching for Learning programme is for anyone who is teaching, or who would like to teach, in any subject and any context - be it at school, at home or in the workplace.                                                          7
#   Recent years have seen a dramatic growth of natural language text data, including web pages, news articles, scientific literature, emails, enterprise documents, and social media such as blog articles, forum posts, product reviews, and tweets.    6
#   Este curso es uno de los 10 cursos disponibles en la colección Goldman Sachs 10,000 Women, diseñado para emprendedoras listas para llevar su negocio al siguiente nivel.                                                                              5
#   This lesson is part of a full course, Business English Networking.                                                                                                                                                                                    5
#                                                                                                                                                                                                                                                        ..
#   Atualmente, grandes intermediários estabelecem confiança em nossa economia e controlam a movimentação, armazenamento e alocação de dinheiro e ativos.                                                                                                 1
#   Este curso te ofrece un entrenamiento para la tarea de descubrir quién será el consumidor de tu producto o servicio y cuáles serán los atributos y características del mismo.                                                                         1
#   Вы растеряны? Утонули в море фактического материала по химии элементов? Хотите уметь предсказывать их свойства? Понять, каких реакций от них можно ожидать? Тогда этот курс для Вас.                                                                  1
#   你可能有一个伟大的游戏创意，但吧想法变成现实不能只知道运用工具。在这个课程中，你将练习如何将游戏的概念转变为设计文档，实现原型以及进行测试。在游戏设计的整个过程中会涉及到许多因素，其中包含以下方面如：产生创意、故事、角色、游戏世界的构建、游戏机制、关卡设计以及用户体验设计。你将会探索如何为你的玩家设计有意义的体验。在这个课程结束时，学员将会完成一份游戏的高概念文档、一页的蓝图、一份实体的原型、提案及辅助设计文档，来将你头脑里的一个想法转变为一份具体、可实施的设计。            1
#   Комбинаторика для начинающих - это базовый курс, закладывающий самые основы комбинаторного знания.                                                                                                                                                    1
#   Name: o, Length: 1710, dtype: int64)]
